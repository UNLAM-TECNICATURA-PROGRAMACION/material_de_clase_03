# %% [markdown]
# <a href="https://colab.research.google.com/github/UNLAM-TECNICATURA-PROGRAMACION/material_de_clase_03/blob/main/Clase_3_1_Funciones_AmbitoVariable_listas_ordenamiento_busqueda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 Funciones, Ámbito, Listas, Ordenamiento y Búsqueda en Python
#
# ## 🎯 Objetivo
# Este cuaderno es una guía práctica para entender y aplicar los conceptos fundamentales de:
# - Funciones
# - Ámbito de variables
# - Listas (arrays)
# - Algoritmos de ordenamiento
# - Algoritmos de búsqueda
#
# ---
#
# ## 🔧 1. Funciones en Python
#
# Una **función** es un bloque de código que se puede reutilizar y ejecutar con diferentes datos.
#
# ```python
# def saludar(nombre):
#     print(f"Hola, {nombre}!")  # Imprime un saludo personalizado
#
# saludar("Alex")
# saludar("Zelda")
# ```
#
# ---
#
# ## 🧠 2. Ámbito de Variables
#
# El **ámbito** define dónde se puede acceder a una variable: **local** (dentro de una función) o **global** (fuera).
#
# ```python
# x = 10  # variable global
#
# def modificar():
#     x = 5  # variable local
#     print("Dentro de la función:", x)
#
# modificar()
# print("Fuera de la función:", x)
# ```
#
# ---
#
# ## 📚 3. Listas (Arrays)
#
# Las **listas** almacenan múltiples valores y permiten muchas operaciones útiles.
#
# ```python
# personajes = ["Mario", "Link", "Samus"]
# print("Segundo personaje:", personajes[1])
#
# personajes.append("Kirby")  # Agregar al final
# print("Lista actualizada:", personajes)
# ```
#
# ---
#
# ## 🔃 4. Ordenamiento
#
# ### ✅ Ordenar con `sort()`
#
# ```python
# niveles = [3, 1, 4, 2]
# niveles.sort()
# print("Ordenado:", niveles)
# ```
#
# ### ✅ Ordenar sin modificar la lista original con `sorted()`
#
# ```python
# original = [8, 3, 5]
# ordenado = sorted(original)
# print("Original:", original)
# print("Ordenado:", ordenado)
# ```
#
# ---
#
# ## 🔍 5. Búsqueda
#
# ### Búsqueda Secuencial
#
# ```python
# def buscar(lista, objetivo):
#     for i, valor in enumerate(lista):
#         if valor == objetivo:
#             return i  # Encontrado
#     return -1  # No encontrado
#
# print(buscar([10, 20, 30], 20))  # → 1
# print(buscar([10, 20, 30], 25))  # → -1
# ```
#
# ---
#
# ## 🚀 Desafío Final Resuelto
#
# Crea una función que:
# - Reciba una lista de puntajes
# - Ordene de mayor a menor
# - Busque un puntaje específico y devuelva su posición
#
# ```python
# def procesar_puntajes(puntajes, objetivo):
#     ordenados = sorted(puntajes, reverse=True)
#     print("Puntajes ordenados:", ordenados)
#
#     if objetivo in ordenados:
#         indice = ordenados.index(objetivo)
#         print(f"El puntaje {objetivo} está en la posición {indice} del ranking.")
#     else:
#         print(f"El puntaje {objetivo} no está en el ranking.")
#
# procesar_puntajes([320, 540, 200, 450], 450)
# ```
#
# ---
#
# ## 🕹️ ¿Y ahora qué?
# - Intentá modificar los valores, agregar funciones propias y experimentar.
# - ¡Jugá con el código como si fuera un nivel más por superar!
