# %% [markdown]
# # Cuaderno de Práctica: Funciones en Python---# Programación Inicial para VideojuegosEste cuaderno contiene ejercicios para practicar la creación y el uso de funciones en Python.Antes de comenzar, repasaremos algunos conceptos importantes que vamos a utilizar en los ejercicios:---# Índice de Contenidos- [¿Qué es una función en Python?](#qué-es-una-función-en-python)- [¿Qué vamos a practicar?](#qué-vamos-a-practicar)- [Punto 1: Crear una función simple](#punto-1-crear-una-función-simple)- [Punto 2: Funciones con parámetros](#punto-2-funciones-con-parámetros)- [Punto 3: Funciones que devuelven valores](#punto-3-funciones-que-devuelven-valores)- [Punto 4: Funciones con valores por defecto](#punto-4-funciones-con-valores-por-defecto)- [Punto 5: Funciones que usan listas](#punto-5-funciones-que-usan-listas)- [Punto 6: Funciones con condicionales](#punto-6-funciones-con-condicionales)- [Punto 7: Funciones con bucles](#punto-7-funciones-con-bucles)- [Desafíos Opcionales 🏆](#desafíos-opcionales-)- [Práctica Final: Mini-juego de Puntos](#práctica-final-mini-juego-de-puntos)- [✨ ¡Fin de la Práctica! ✨](#-fin-de-la-práctica-)---# ¿Qué es una función en Python?Una **función** es un bloque de código reutilizable que realiza una tarea específica. Nos permite organizar mejor el código y evitar repeticiones.**Sintaxis básica:**```pythondef nombre_funcion(parámetros):    # Bloque de instrucciones    return resultado (opcional)```... (continúa igual)
